# %%
# %matplotlib inline

import sqlite3
import json
import csv
import pandas as pd
import numpy as np
import nltk
import string
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import re

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.pipeline import FeatureUnion
from sklearn.base import BaseEstimator, TransformerMixin

from nltk.stem.porter import PorterStemmer

from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# ## Reading data from JSON file

# %%
df = pd.read_json('reviews_merged.json')

# %%
df
# Out:
#               asin   helpful  overall  \
# 0       7806397051    [3, 4]        1
# 1       7806397051    [1, 1]        3
# 2       7806397051    [0, 1]        4
# 3       7806397051    [2, 2]        2
# 4       7806397051    [0, 0]        3
# 5       7806397051    [1, 2]        5
# 6       7806397051    [1, 3]        1
# 7       7806397051    [0, 1]        2
# 8       9759091062    [0, 0]        2
# 9       9759091062    [0, 0]        3
# 10      9759091062    [0, 0]        3
# 11      9759091062    [0, 0]        1
# 12      9759091062    [0, 1]        5
# 13      9759091062    [0, 0]        1
# 14      9759091062    [0, 1]        5
# 15      9759091062    [0, 0]        2
# 16      9759091062    [2, 4]        5
# 17      9759091062    [2, 4]        4
# 18      9759091062    [0, 1]        3
# 19      9788072216  [24, 24]        5
# 20      9788072216    [0, 0]        5
# 21      9788072216    [1, 1]        5
# 22      9788072216    [2, 4]        5
# 23      9788072216    [0, 0]        5
# 24      9790790961    [1, 1]        5
# 25      9790790961    [0, 1]        3
# 26      9790790961    [0, 0]        5
# 27      9790790961    [0, 1]        5
# 28      9790790961    [1, 2]        5
# 29      9790790961    [0, 0]        3
# ...            ...       ...      ...
# 477149  B00KA602SY    [0, 0]        5
# 477150  B00KCWMG5S    [0, 0]        2
# 477151  B00KCWMG5S    [2, 2]        4
# 477152  B00KCWMG5S    [0, 0]        3
# 477153  B00KCWMG5S    [1, 1]        1
# 477154  B00KCWMG5S    [0, 0]        2
# 477155  B00KF9180W    [1, 1]        5
# 477156  B00KF9180W    [1, 1]        5
# 477157  B00KF9180W    [2, 3]        5
# 477158  B00KF9180W    [4, 5]        5
# 477159  B00KF9180W    [4, 5]        4
# 477160  B00KF9180W    [4, 7]        5
# 477161  B00KF9180W    [5, 6]        5
# 477162  B00KF9180W    [2, 3]        5
# 477163  B00KF9180W    [7, 8]        5
# 477164  B00KF9180W    [2, 3]        4
# 477165  B00KGCLROK    [1, 1]        2
# 477166  B00KGCLROK    [0, 0]        5
# 477167  B00KGCLROK    [0, 0]        5
# 477168  B00KGCLROK    [1, 1]        5
# 477169  B00KGCLROK    [0, 0]        5
# 477170  B00KKXCJQU    [1, 1]        5
# 477171  B00KKXCJQU    [0, 0]        5
# 477172  B00KKXCJQU    [2, 2]        5
# 477173  B00KKXCJQU    [1, 1]        5
# 477174  B00KKXCJQU    [0, 1]        5
# 477175  B00KKXCJQU    [0, 0]        5
# 477176  B00KKXCJQU    [1, 1]        5
# 477177  B00KKXCJQU    [2, 2]        5
# 477178  B00KKXCJQU    [0, 1]        5
#
#                                                reviewText   reviewTime  \
# 0       Very oily and creamy. Not at all what I expect...  01 30, 2014
# 1       This palette was a decent price and I was look...  04 18, 2014
# 2       The texture of this concealer pallet is fantas...   09 6, 2013
# 3       I really can't tell what exactly this thing is...   12 8, 2013
# 4       It was a little smaller than I expected, but t...  10 19, 2013
# 5       I was very happy to get this palette, now I wi...  04 15, 2013
A30VWT3R25QAVD          THE-DEADLY-DOG "Living and Loving Life."
#
#                                                   summary  unixReviewTime
# 0                                  Don't waste your money      1391040000
# 1                                             OK Palette!      1397779200
# 2                                           great quality      1378425600
# 3                                  Do not work on my face      1386460800
# 4                                              It's okay.      1382140800
# 5                                      Very nice palette!      1365984000
# 6                                                  smh!!!      1376611200
# 7       Chalky, Not Pigmented, Wears off easily, Not a...      1378252800
# 8             no Lightening, no Brightening,......NOTHING      1405209600
# 9                                             Its alright      1388102400
# 10                                        Mixed feelings.      1400544000
# 11                                                Nothing      1392681600
# 12                                             This works      1390435200
# 13                                           Does nothing      1389398400
# 14                                               it works      1392681600
# 15                                                  burns      1396742400
# 16                                        Did work for me      1379116800
# 17                                              excellent      1382054400
# 18                                            weird smell      1383264000
# 19                                Love the smell of this!      1316390400
# 20                                                  Happy      1376092800
# 21                                              Very good      1322438400
# 22                                       Lurrrrrrrrv.....      1338076800
# 23                                            Great Scent      1359763200
# 24                              Spring Garden in a Bottle      1394496000
# 25                                            fresh smell      1324252800
# 26                                          My new smell!      1378598400
# 27                                        One of my favs!      1391299200
# 28                                           Smells clean      1392336000
# 29       Love the smell but a shame it's not last as long      1392163200
# ...                                                   ...             ...
# 477149                                          Very nice      1403395200
# 477150                                        Teeny pants      1405814400
# 477151                                     fabric is thin      1402012800
# 477152                                  so, this is weird      1404691200
# 477153                                            Stained      1403481600
# 477154                                     just too small      1401926400
# 477155           Quality set with multiple configurations      1403827200
# 477156  I&#8217;m ready for another frigid blast (or a...      1402099200
# 477157  Wonderful for one who is outdoors in cold weat...      1401840000
# 477158  Look Mom I'm a Ninja...No, I'm a Motorcycle  M...      1402876800
# 477159                   Great for Winter or Chilly Walks      1402876800
# 477160        Nice soft protection from the elements.....      1402272000
# 477161  Love that my ears have two layers of protectio...      1402617600
# 477162  Balaclava 2 Pack - Black - Tan - 100% Polyeste...      1402617600
# 477163                     Fits under even a tight helmet      1403308800
# 477164                               Lightweight & useful      1402272000
# 477165                               Wanted to love these      1403308800
# 477166   My stepmother was impressed with the extra grip.      1404345600
# 477167     A bit fussy to get on, but they work very well      1403395200
# 477168  Very nice, comfortable non-slip socks for yoga...      1404518400
# 477169                                              Cozy!      1403568000
# 477170                            Even Husbands can do it      1402272000
# 477171                                    Not for squares      1405641600
# 477172  Can be used for organization but they are grea...      1402617600
# 477173             End of my packing nightmare system ...      1402272000
# 477174     These have literally changed the way I travel!      1403568000
# 477175                       Wonderful for Better Packing      1403740800
# 477176               Convenient, lightweight, and durable      1402185600
# 477177                   Holds Up Well In Real World Test      1404691200
# 477178  Don't Travel? Still Way too Useful for 'Averag...      1403481600
#
# [477179 rows x 9 columns]

# %% [markdown]
# ## New Dataframe having only helpful attribute and productID

# %%
helpfulness = df[['helpful','asin']]

# %%
helpfulness
# Out:
#          helpful        asin
# 0         [3, 4]  7806397051
# 1         [1, 1]  7806397051
# 2         [0, 1]  7806397051
# 3         [2, 2]  7806397051
# 4         [0, 0]  7806397051
# 5         [1, 2]  7806397051
# 6         [1, 3]  7806397051
# 7         [0, 1]  7806397051
# 8         [0, 0]  9759091062
# 9         [0, 0]  9759091062
# 10        [0, 0]  9759091062
# 11        [0, 0]  9759091062
# 12        [0, 1]  9759091062
# 13        [0, 0]  9759091062
# 14        [0, 1]  9759091062
# 15        [0, 0]  9759091062
# 16        [2, 4]  9759091062
# 17        [2, 4]  9759091062
# 18        [0, 1]  9759091062
# 19      [24, 24]  9788072216
# 20        [0, 0]  9788072216
# 21        [1, 1]  9788072216
# 22        [2, 4]  9788072216
# 23        [0, 0]  9788072216
# 24        [1, 1]  9790790961
# 25        [0, 1]  9790790961
# 26        [0, 0]  9790790961
# 27        [0, 1]  9790790961
# 28        [1, 2]  9790790961
# 29        [0, 0]  9790790961
# ...          ...         ...
# 477149    [0, 0]  B00KA602SY
# 477150    [0, 0]  B00KCWMG5S
# 477151    [2, 2]  B00KCWMG5S
# 477152    [0, 0]  B00KCWMG5S
# 477153    [1, 1]  B00KCWMG5S
# 477154    [0, 0]  B00KCWMG5S
# 477155    [1, 1]  B00KF9180W
# 477156    [1, 1]  B00KF9180W
# 477157    [2, 3]  B00KF9180W
# 477158    [4, 5]  B00KF9180W
# 477159    [4, 5]  B00KF9180W
# 477160    [4, 7]  B00KF9180W
# 477161    [5, 6]  B00KF9180W
# 477162    [2, 3]  B00KF9180W
# 477163    [7, 8]  B00KF9180W
# 477164    [2, 3]  B00KF9180W
# 477165    [1, 1]  B00KGCLROK
# 477166    [0, 0]  B00KGCLROK
# 477167    [0, 0]  B00KGCLROK
# 477168    [1, 1]  B00KGCLROK
# 477169    [0, 0]  B00KGCLROK
# 477170    [1, 1]  B00KKXCJQU
# 477171    [0, 0]  B00KKXCJQU
# 477172    [2, 2]  B00KKXCJQU
# 477173    [1, 1]  B00KKXCJQU
# 477174    [0, 1]  B00KKXCJQU
# 477175    [0, 0]  B00KKXCJQU
# 477176    [1, 1]  B00KKXCJQU
# 477177    [2, 2]  B00KKXCJQU
# 477178    [0, 1]  B00KKXCJQU
#
# [477179 rows x 2 columns]

# %%
df2 = pd.DataFrame(helpfulness)

# %%
df2[['helpful','total']] = pd.DataFrame(df2.helpful.values.tolist(), index=df2.index)
dfhelpful = df2[['asin', 'helpful','total']]

# %%
dfhelpful
# Out:
#               asin  helpful  total
# 0       7806397051        3      4
# 1       7806397051        1      1
# 2       7806397051        0      1
# 3       7806397051        2      2
# 4       7806397051        0      0
# 5       7806397051        1      2
# 6       7806397051        1      3
# 7       7806397051        0      1
# 8       9759091062        0      0
# 9       9759091062        0      0
# 10      9759091062        0      0
# 11      9759091062        0      0
# 12      9759091062        0      1
# 13      9759091062        0      0
# 14      9759091062        0      1
# 15      9759091062        0      0
# 16      9759091062        2      4
# 17      9759091062        2      4
# 18      9759091062        0      1
# 19      9788072216       24     24
# 20      9788072216        0      0
# 21      9788072216        1      1
# 22      9788072216        2      4
# 23      9788072216        0      0
# 24      9790790961        1      1
# 25      9790790961        0      1
# 26      9790790961        0      0
# 27      9790790961        0      1
# 28      9790790961        1      2
# 29      9790790961        0      0
# ...            ...      ...    ...
# 477149  B00KA602SY        0      0
# 477150  B00KCWMG5S        0      0
# 477151  B00KCWMG5S        2      2
# 477152  B00KCWMG5S        0      0
# 477153  B00KCWMG5S        1      1
# 477154  B00KCWMG5S        0      0
# 477155  B00KF9180W        1      1
# 477156  B00KF9180W        1      1
# 477157  B00KF9180W        2      3
# 477158  B00KF9180W        4      5
# 477159  B00KF9180W        4      5
# 477160  B00KF9180W        4      7
# 477161  B00KF9180W        5      6
# 12                                             This works      1390435200
# 13                                           Does nothing      1389398400
# 14                                               it works      1392681600
# 15                                                  burns      1396742400
# 16                                        Did work for me      1379116800
# 17                                              excellent      1382054400
# 18                                            weird smell      1383264000
# 19                                Love the smell of this!      1316390400
# 20                                                  Happy      1376092800
# 21                                              Very good      1322438400
# 22                                       Lurrrrrrrrv.....      1338076800
# 23                                            Great Scent      1359763200
# 24                              Spring Garden in a Bottle      1394496000
# 25                                            fresh smell      1324252800
# 26                                          My new smell!      1378598400
# 27                                        One of my favs!      1391299200
# 28                                           Smells clean      1392336000
# 29       Love the smell but a shame it's not last as long      1392163200
# ...                                                   ...             ...
# 477149                                          Very nice      1403395200
# 477150                                        Teeny pants      1405814400
# 477151                                     fabric is thin      1402012800
# 477152                                  so, this is weird      1404691200
# 477153                                            Stained      1403481600
# 477154                                     just too small      1401926400
# 477155           Quality set with multiple configurations      1403827200
# 477156  I&#8217;m ready for another frigid blast (or a...      1402099200
# 477157  Wonderful for one who is outdoors in cold weat...      1401840000
# 477158  Look Mom I'm a Ninja...No, I'm a Motorcycle  M...      1402876800
# 477159                   Great for Winter or Chilly Walks      1402876800
# 477160        Nice soft protection from the elements.....      1402272000
# 477161  Love that my ears have two layers of protectio...      1402617600
# 477162  Balaclava 2 Pack - Black - Tan - 100% Polyeste...      1402617600
# 477163                     Fits under even a tight helmet      1403308800
# 477164                               Lightweight & useful      1402272000
# 477165                               Wanted to love these      1403308800
# 477166   My stepmother was impressed with the extra grip.      1404345600
# 477167     A bit fussy to get on, but they work very well      1403395200
# 477168  Very nice, comfortable non-slip socks for yoga...      1404518400
# 477169                                              Cozy!      1403568000
# 477170                            Even Husbands can do it      1402272000
# 477171                                    Not for squares      1405641600
# 477172  Can be used for organization but they are grea...      1402617600
# 477173             End of my packing nightmare system ...      1402272000
# 477174     These have literally changed the way I travel!      1403568000
# 477175                       Wonderful for Better Packing      1403740800
# 477176               Convenient, lightweight, and durable      1402185600
# 477177                   Holds Up Well In Real World Test      1404691200
# 477178  Don't Travel? Still Way too Useful for 'Averag...      1403481600
#
#         helpful  total
# 0             3      4
# 1             1      1
# 2             0      1
# 3             2      2
# 4             0      0
# 5             1      2
# 6             1      3
# 7             0      1
# 8             0      0
# 9             0      0
# 10            0      0
# 11            0      0
# 12            0      1
# 13            0      0
# 14            0      1
# 15            0      0
# 16            2      4
# 17            2      4
# 18            0      1
# 19           24     24
# 20            0      0
# 21            1      1
# 22            2      4
# 23            0      0
# 24            1      1
# 25            0      1
# 26            0      0
# 27            0      1
# 28            1      2
# 29            0      0
# ...         ...    ...
# 477149        0      0
# 477150        0      0
# 477151        2      2
# 477152        0      0
# 477153        1      1
# 477154        0      0
# 477155        1      1
# 477156        1      1
# 477157        2      3
# 477158        4      5
# 477159        4      5
# 477160        4      7
# 477161        5      6
# 477162        2      3
# 477163        7      8
# 477164        2      3
# 477165        1      1
# 477166        0      0
# 477167        0      0
# 477168        1      1
# 477169        0      0
# 477170        1      1
# 477171        0      0
# 477172        2      2
# 477173        1      1
# 477174        0      1
# 477175        0      0
# 477176        1      1
# 477177        2      2
# 477178        0      1
#
# [477179 rows x 10 columns]

# %%
result.to_csv('reviews.csv', sep=',', header=False,index=False)

# %%
result
# Out:
#               asin  overall  \
# 0       7806397051        1
# 1       7806397051        3
# 2       7806397051        4
# 3       7806397051        2
# 4       7806397051        3
# 5       7806397051        5
# 6       7806397051        1
# 7       7806397051        2
# 8       9759091062        2
# 9       9759091062        3
# 10      9759091062        3
# 11      9759091062        1
# 12      9759091062        5
# 13      9759091062        1
# 14      9759091062        5
# 15      9759091062        2
# 16      9759091062        5
# 17      9759091062        4
# 18      9759091062        3
# 19      9788072216        5
# 20      9788072216        5
# 21      9788072216        5
# 22      9788072216        5
# 23      9788072216        5
# 24      9790790961        5
# 25      9790790961        3
# 26      9790790961        5
# 27      9790790961        5
# 28      9790790961        5
# 29      9790790961        3
# ...            ...      ...
# 477149  B00KA602SY        5
# 477150  B00KCWMG5S        2
# 477151  B00KCWMG5S        4
# 477152  B00KCWMG5S        3
# 477153  B00KCWMG5S        1
# 477154  B00KCWMG5S        2
# 477155  B00KF9180W        5
# 477156  B00KF9180W        5
# 477157  B00KF9180W        5
# 477158  B00KF9180W        5
# 477159  B00KF9180W        4
# 477160  B00KF9180W        5
# 477161  B00KF9180W        5
# 477162  B00KF9180W        5
# 477163  B00KF9180W        5
# 477164  B00KF9180W        4
# 477165  B00KGCLROK        2
# 477166  B00KGCLROK        5
# 477167  B00KGCLROK        5
# 477168  B00KGCLROK        5
# 477169  B00KGCLROK        5
# 477170  B00KKXCJQU        5
# 477171  B00KKXCJQU        5
# 477172  B00KKXCJQU        5
# 477173  B00KKXCJQU        5
# 477174  B00KKXCJQU        5
# 477175  B00KKXCJQU        5
# 477176  B00KKXCJQU        5
# 477177  B00KKXCJQU        5
# 477178  B00KKXCJQU        5
#
#                                                reviewText   reviewTime  \
# 0       Very oily and creamy. Not at all what I expect...  01 30, 2014
# 1       This palette was a decent price and I was look...  04 18, 2014
# 2       The texture of this concealer pallet is fantas...   09 6, 2013
# 3       I really can't tell what exactly this thing is...   12 8, 2013
# 4       It was a little smaller than I expected, but t...  10 19, 2013
# 5       I was very happy to get this palette, now I wi...  04 15, 2013
# 6       PLEASE DONT DO IT! this just rachett the palet...  08 16, 2013
# 7       Chalky,Not Pigmented,Wears off easily,Not a Co...   09 4, 2013
# 8       Did nothing for me. Stings when I put it on. I...  07 13, 2014
# 9       I bought this product to get rid of the dark s...  12 27, 2013
# 10      I have mixed feelings about this product. When...  05 20, 2014
# 11      Did nothing for my skin. Used as suggested and...  02 18, 2014
# 12      I bought this product about 3 months ago, I fi...  01 23, 2014
# 13      This gell did nothing at all. I religiously pu...  01 11, 2014
# 14      i got this to get rid of a scar and it did jus...  02 18, 2014
# 15      I used it for anal bleaching and it burned a b...   04 6, 2014
# 16      I order this cream along with their soap. It a...  09 14, 2013
# 17      Good product. Use a little bit on your spot an...  10 18, 2013
# 18      I didn't use it past a week. The reason why is...   11 1, 2013
# 19      I haven't been a big fan of Prada's fragrances...  09 19, 2011
# 20      We gave these as gifts and everyone that recei...  08 10, 2013
# 21      This is the first fragrance by Prada that I lo...  11 28, 2011
# 22      So I got this about a month ago. I had no plan...  05 27, 2012
# 23      This product has a very fruity scent which is ...   02 2, 2013
# 24      I'm very picky when it comes to fragrance. I l...  03 11, 2014
# 25      bright crystals reminds me of Victoria Secrets...  12 19, 2011
# 26      Got this product and I never heard of this so ...   09 8, 2013
# 27      This is a beautiful perfume! Nice, clean scent...   02 2, 2014
# 28      This is the real Versace Bright Crystal fragra...  02 14, 2014
# 29      I love it! and will continue using it but it's...  02 12, 2014
# ...                                                   ...          ...
# 477149  I really like this shirt, very comfortable and...  06 22, 2014
# 477150                                For tiny teenagers.  07 20, 2014
# 477151  Like these pants, 1st time I wore them I rippe...   06 6, 2014
# 477152  I should have waited until I owned the first p...   07 7, 2014
# 477153  Arrived with what looked like a bleach stain o...  06 23, 2014
# 477154  Trying to decide if return or just give away t...   06 5, 2014
# 477155  This is a (2) pack of balcalavas that can be c...  06 27, 2014
# 477156  I really wish I had these a few months ago whe...   06 7, 2014
# 477157  If you are an outdoor person and are outdoors ...   06 4, 2014
# 477158  l  know now just what I am going as for Hallow...  06 16, 2014
# 477159  I go walking a lot in all kinds of weather and...  06 16, 2014
# 477160  This two pack of Balaclavas makes for a very n...   06 9, 2014
# 477161  Well, the first thing I did was try the balacl...  06 13, 2014
# 477162  While balaclavas can be used for a variety of ...  06 13, 2014
# 477163  This is truly a year round product. Here in th...  06 21, 2014
# 477164  Nice material, but not as nice as  silk or mer...   06 9, 2014
# 477165  These were a free sample for review.  I was ex...  06 21, 2014
# 477166  My stepmother does yoga in bare feet or regula...   07 3, 2014
# 477167  These socks are very nicely made and quite com...  06 22, 2014
# 477168  You don&#8217;t have to be a yoga or martial a...   07 5, 2014
# 477169  These are cozy and complements well for yoga. ...  06 24, 2014
# 477170  I really hate my husband's packing system. He ...   06 9, 2014
# 477171  *Disclosure: I was contacted by a rep for Shac...  07 18, 2014
# 477172  This set of travel organizers includes four pi...  06 13, 2014
# 477173  When I pack it looks like a disaster area in a...   06 9, 2014
# 477174  I don't normally go ga-ga over a product very ...  06 24, 2014
# 477175  I've been traveling back and forth to England ...  06 26, 2014
# 477176  These are very nice packing cubes and the 18 x...   06 8, 2014
# 477177  I am on vacation with my family of four and th...   07 7, 2014
# 477178  When I signed up to receive a free set of Shac...  06 23, 2014
#
#             reviewerID                                      reviewerName  \
# 0       A1YJEY40YUW4SE                                            Andrea
# 1        A60XNB876KYML                                        Jessica H.
# 2       A3G6XNM240RMWA                                             Karen
# 3       A1PQFP6SAJ6D80                                             Norah
# 4       A38FVHZTNQ271F                                         Nova Amor
# 5       A3BTN14HIZET6Z                    S. M. Randall "WildHorseWoman"
# 6       A1Z59RFKN0M5QL                                 tasha "luvely12b"
# 7        AWUO9P6PL1SY8                                     TreMagnifique
# 8       A3LMILRM9OC3SA                                               NaN
# 9       A30IP88QK3YUIO                               Amina Bint Ibraheem
# 10       APBQH4BS48CQO                                           Charmmy
# 11      A3FE8W8UV95U6B                                 Culture C Simmons
# 12      A1EVGDOTGFZOSS                           Jessica "Anarchykisses"
# 13       AP5WTCMP6DTRV                                           Layla B
# 14      A21IM16PQWKVO5                                          mdub9922
# 15      A1TLDR1V4O48PK                     Mickey O Neil "Mickey O Neil"
# 16       A6F8KH0J1AVYA                                            SanBen
# 17       AXPKZA7UZXKTT                                         Shirleyyy
# 18      A2SIAYDK7GG7QA                                      theredtranny
# 19      A1QV5IH6HDRN0L                                          armygirl
# 20      A3UQXHI88S7XAX                                         D. Greene
# 21      A2EK2CJNJUF7OQ                                             Nikki
Look Mom I'm a Ninja...No, I'm a Motorcycle  M...      1402876800
# 477159                   Great for Winter or Chilly Walks      1402876800
# 477160        Nice soft protection from the elements.....      1402272000
# 477161  Love that my ears have two layers of protectio...      1402617600
# 477162  Balaclava 2 Pack - Black - Tan - 100% Polyeste...      1402617600
# 477163                     Fits under even a tight helmet      1403308800
# 477164                               Lightweight & useful      1402272000
# 477165                               Wanted to love these      1403308800
# 477166   My stepmother was impressed with the extra grip.      1404345600
# 477167     A bit fussy to get on, but they work very well      1403395200
# 477168  Very nice, comfortable non-slip socks for yoga...      1404518400
# 477169                                              Cozy!      1403568000
# 477170                            Even Husbands can do it      1402272000
# 477171                                    Not for squares      1405641600
# 477172  Can be used for organization but they are grea...      1402617600
# 477173             End of my packing nightmare system ...      1402272000
# 477174     These have literally changed the way I travel!      1403568000
# 477175                       Wonderful for Better Packing      1403740800
# 477176               Convenient, lightweight, and durable      1402185600
# 477177                   Holds Up Well In Real World Test      1404691200
# 477178  Don't Travel? Still Way too Useful for 'Averag...      1403481600
#
#         helpful  total
# 0             3      4
# 1             1      1
# 2             0      1
# 3             2      2
# 4             0      0
# 5             1      2
# 6             1      3
# 7             0      1
# 8             0      0
# 9             0      0
# 10            0      0
# 11            0      0
# 12            0      1
# 13            0      0
# 14            0      1
# 15            0      0
# 16            2      4
# 17            2      4
# 18            0      1
# 19           24     24
# 20            0      0
# 21            1      1
# 22            2      4
# 23            0      0
# 24            1      1
# 25            0      1
# 26            0      0
# 27            0      1
# 28            1      2
# 29            0      0
# ...         ...    ...
# 477149        0      0
# 477150        0      0
# 477151        2      2
# 477152        0      0
# 477153        1      1
# 477154        0      0
# 477155        1      1
# 477156        1      1
# 477157        2      3
# 477158        4      5
# 477159        4      5
# 477160        4      7
# 477161        5      6
# 477162        2      3
# 477163        7      8
# 477164        2      3
# 477165        1      1
# 477166        0      0
# 477167        0      0
# 477168        1      1
# 477169        0      0
# 477170        1      1
# 477171        0      0
# 477172        2      2
# 477173        1      1
# 477174        0      1
# 477175        0      0
# 477176        1      1
# 477177        2      2
# 477178        0      1
#
# [477179 rows x 10 columns]

# %% [markdown]
# ## Loading csv to SQLite
# Fetch the score and recommendation summary using SQL queries

# %%
class csvrd(object):
    def csvFile(self):

        self.readFile('reviews.csv')

    def readFile(self, filename):
        conn = sqlite3.connect('amazonReviews.db')
        cur = conn.cursor() 
        cur.execute("""CREATE TABLE IF NOT EXISTS amazonReviews(asin INT,overall INT,reviewText varchar,reviewTime INTEGER, reviewerID varchar,reviewerName varchar,summary varchar,unixReviewTime INTEGER,helpful INT,total INT)""")
        filename.encode('utf-8')
        print "Amazon Reviews table executed"
        with open(filename) as f:
            reader = csv.reader(f)
            for field in reader:
                cur.execute("INSERT INTO amazonReviews VALUES (?,?,?,?,?,?,?,?,?,?);", field)

        print "CSV Loaded into SQLite"
        conn.commit()
        conn.close()

c = csvrd().csvFile()
# Out:
# Amazon Reviews table executed
# CSV Loaded into SQLite

# %% [markdown]
# ## Reading the data from SQLite

# %%
con = sqlite3.connect('amazonReviews.db')

pd.read_sql_query("SELECT * FROM amazonReviews LIMIT 5", con)
# Out:
#          asin  overall                                         reviewText  \
# 0  7806397051        1  Very oily and creamy. Not at all what I expect...
# 1  7806397051        3  This palette was a decent price and I was look...
# 2  7806397051        4  The texture of this concealer pallet is fantas...
# 3  7806397051        2  I really can't tell what exactly this thing is...
# 4  7806397051        3  It was a little smaller than I expected, but t...
#
#     reviewTime      reviewerID reviewerName                 summary  \
# 0  01 30, 2014  A1YJEY40YUW4SE       Andrea  Don't waste your money
# 1  04 18, 2014   A60XNB876KYML   Jessica H.             OK Palette!
# 2   09 6, 2013  A3G6XNM240RMWA        Karen           great quality
# 3   12 8, 2013  A1PQFP6SAJ6D80        Norah  Do not work on my face
# 4  10 19, 2013  A38FVHZTNQ271F    Nova Amor              It's okay.
#
#    unixReviewTime  helpful  total
# 0      1391040000        3      4
# 1      1397779200        1      1
# 2      1378425600        0      1
# 3      1386460800        2      2
# 4      1382140800        0      0

# %% [markdown]
# ignoring the reviews having overall score equal to 3.
# If the overall score is above 3, then the label for it will be set to Positive
# else it will be set to Negative

# %%
reviews = pd.read_sql_query("""
SELECT 
  overall, 
  summary, 
  helpful, 
  total
FROM amazonReviews 
WHERE overall != 3""", con)

# %%
#display data
reviews.head(5)
# Out:
#    overall                 summary  helpful  total
# 0        1  Don't waste your money        3      4
# 1        4           great quality        0      1
# 2        2  Do not work on my face        2      2
# 3        5      Very nice palette!        1      2
# 4        1                  smh!!!        1      3

# %% [markdown]
# sentiment column depicts the numeric score of being positive or negative
# usefulScore column depicts the boolean value of total number of votes

# %%
reviews["sentiment"] = reviews["overall"].apply(lambda score: "positive" if score > 3 else "negative")
reviews["usefulScore"] = (reviews["helpful"]/reviews["total"]).apply(lambda n: "useful" if n > 0.8 else "useless")

reviews.head(5)
# Out:
#    overall                 summary  helpful  total sentiment usefulScore
# 0        1  Don't waste your money        3      4  negative     useless
# 1        4           great quality        0      1  positive     useless
# 2        2  Do not work on my face        2      2  negative      useful
# 3        5      Very nice palette!        1      2  positive     useless
# 4        1                  smh!!!        1      3  negative     useless

# %% [markdown]
# Rows having overall score equal to 5

# %%
reviews[reviews.overall == 5].head(5)
# Out:
#     overall                  summary  helpful  total sentiment usefulScore
# 3         5       Very nice palette!        1      2  positive     useless
# 8         5               This works        0      1  positive     useless
# 10        5                 it works        0      1  positive     useless
# 12        5          Did work for me        2      4  positive     useless
# 14        5  Love the smell of this!       24     24  positive      useful

# %%
#Rows having overall score equal to 1
reviews[reviews.overall == 1].head(5)
# Out:
#     overall                 summary  helpful  total sentiment usefulScore
# 0         1  Don't waste your money        3      4  negative     useless
# 4         1                  smh!!!        1      3  negative     useless
# 7         1                 Nothing        0      0  negative     useless
# 9         1            Does nothing        0      0  negative     useless
# 32        1             Bad product        0      0  negative     useless

# %% [markdown]
# ## Feature extraction from reviewsText
# Assign new dimension to each word and give the word counts

# %%
regEx = re.compile('[^a-z]+')
def cleanReviews(reviewText):
    reviewText = reviewText.lower()
    reviewText = regEx.sub(' ', reviewText).strip()
    return reviewText

reviews["summaryClean"] = reviews["summary"].apply(cleanReviews)

train, test = train_test_split(reviews, test_size=0.2)
print("%d items in training data, %d in test data" % (len(train), len(test)))
# Out:
# 1018814 items in training data, 254704 in test data

# %% [markdown]
# ### Using TfidfTransformer().fit_transofrm
# to fit the train and test data

# %%
countVector = CountVectorizer(min_df = 1, ngram_range = (1, 4))
X_train_counts = countVector.fit_transform(train["summaryClean"])

#applying tfidf to term frequency
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

X_new_counts = countVector.transform(test["summaryClean"])
X_test_tfidf = tfidf_transformer.transform(X_new_counts)

y_train = train["sentiment"]
y_test = test["sentiment"]

prediction = dict()

# %%
stopwords = set(STOPWORDS)

#mpl.rcParams['figure.figsize']=(8.0,6.0)    #(6.0,4.0)
mpl.rcParams['font.size']=12                #10 
mpl.rcParams['savefig.dpi']=100             #72 
mpl.rcParams['figure.subplot.bottom']=.1 


def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))
    
    fig = plt.figure(1, figsize=(8, 8))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()
    
show_wordcloud(reviews["summaryClean"])

# %%
show_wordcloud(reviews[reviews.overall == 1]["summaryClean"], title = "Low scored words")

# %%
show_wordcloud(reviews[reviews.overall == 5]["summaryClean"], title = "High scored words")

# %%
show_wordcloud(reviews[reviews.overall == 2]["summaryClean"], title = "Average scored words")

# %% [markdown]
# ## Multinomial Naïve Bayes learning method

# %%
model = MultinomialNB().fit(X_train_tfidf, y_train)
prediction['Multinomial'] = model.predict(X_test_tfidf)

# %% [markdown]
# ## Bernoulli Naïve Bayes learning method

# %%
model = BernoulliNB().fit(X_train_tfidf, y_train)
prediction['Bernoulli'] = model.predict(X_test_tfidf)

# %% [markdown]
# ## Logistic regression learning method

# %%
logreg = LogisticRegression(C=1e5)
logreg_result = logreg.fit(X_train_tfidf, y_train)
prediction['Logistic'] = logreg.predict(X_test_tfidf)

# %% [markdown]
# ### Results

# %%
def formatt(x):
    if x == 'negative':
        return 0
    return 1
vfunc = np.vectorize(formatt)

cmp = 0
colors = ['b', 'g', 'y', 'm', 'k']
for model, predicted in prediction.items():
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test.map(formatt), vfunc(predicted))
    roc_auc = auc(false_positive_rate, true_positive_rate)
    plt.plot(false_positive_rate, true_positive_rate, colors[cmp], label='%s: AUC %0.2f'% (model,roc_auc))
    cmp += 1

plt.title('Classifiers comparaison with ROC')
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ### Visualize the accuracy, recall and f1-score for Logistic Regression

# %%
print(metrics.classification_report(y_test, prediction['Logistic'], target_names = ["positive", "negative"]))
# Out:
#              precision    recall  f1-score   support
#
#    positive       0.96      0.92      0.94     29561
#    negative       0.99      0.99      0.99    225143
#
# avg / total       0.99      0.99      0.99    254704

# %%
accuracy_score(y_test, prediction['Logistic'])
# Out:
# 0.98621929769457883

# %%
def plot_confusion_matrix(matrix, title='Confusion matrix', cmap=plt.cm.Blues, labels=["positive", "negative"]):
    plt.imshow(matrix, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45)
    plt.yticks(tick_marks, labels)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
# Compute confusion matrix
matrix = confusion_matrix(y_test, prediction['Logistic'])
np.set_printoptions(precision=2)
plt.figure()
plot_confusion_matrix(matrix)    

matrix_normalized = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
plt.figure()
plot_confusion_matrix(matrix_normalized, title='Normalized confusion matrix')
plt.show()

# %% [markdown]
# ### Visualize the accuracy, recall and f1-score for Naive Bayes Berrnoulli

# %%
print(metrics.classification_report(y_test, prediction['Bernoulli'], target_names = ["positive", "negative"]))
# Out:
#              precision    recall  f1-score   support
#
#    positive       0.59      0.53      0.56     29561
#    negative       0.94      0.95      0.95    225143
#
# avg / total       0.90      0.90      0.90    254704

# %%
accuracy_score(y_test, prediction['Bernoulli'])
# Out:
# 0.90240043344431187

# %%
def plot_confusion_matrix(matrix, title='Confusion matrix', cmap=plt.cm.Blues, labels=["positive", "negative"]):
    plt.imshow(matrix, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45)
    plt.yticks(tick_marks, labels)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
# Compute confusion matrix
matrix = confusion_matrix(y_test, prediction['Bernoulli'])
np.set_printoptions(precision=2)
plt.figure()
plot_confusion_matrix(matrix)    

matrix_normalized = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
plt.figure()
plot_confusion_matrix(matrix_normalized, title='Normalized confusion matrix')
plt.show()

# %% [markdown]
# ### Visualize the accuracy, recall and f1-score for Naive Bayes Multinomial

# %%
print(metrics.classification_report(y_test, prediction['Multinomial'], target_names = ["positive", "negative"]))
# Out:
#              precision    recall  f1-score   support
#
#    positive       0.96      0.63      0.76     29561
#    negative       0.95      1.00      0.97    225143
#
# avg / total       0.95      0.95      0.95    254704

# %%
accuracy_score(y_test, prediction['Multinomial'])
# Out:
# 0.95389157610402664

# %%
def plot_confusion_matrix(matrix, title='Confusion matrix', cmap=plt.cm.Blues, labels=["positive", "negative"]):
    plt.imshow(matrix, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45)
    plt.yticks(tick_marks, labels)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
# Compute confusion matrix
matrix = confusion_matrix(y_test, prediction['Multinomial'])
np.set_printoptions(precision=2)
plt.figure()
plot_confusion_matrix(matrix)    

matrix_normalized = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
plt.figure()
plot_confusion_matrix(matrix_normalized, title='Normalized confusion matrix')
plt.show()

# %% [markdown]
# ### Displaying words depicting the best and worst features
# using Logistic Model since it gave the best results

# %%
features = countVector.get_feature_names()
feature_coefs = pd.DataFrame(
    data = list(zip(features, logreg_result.coef_[0])),
    columns = ['feature', 'coefficient'])

feature_coefs.sort_values(by='coefficient')
# Out:
#                     feature  coefficient
# 1129133               worst   -23.721842
# 669087                  not   -22.421924
# 459300             horrible   -21.047149
# 937168             terrible   -20.607067
# 243655        disappointing   -20.209056
# 131202                broke   -19.465871
# 754760                 poor   -19.209378
# 239888                 didn   -18.284823
# 74496                 awful   -16.628848
# 1038935       uncomfortable   -16.352018
# 1077507               waste   -16.244804
# 1129029               worse   -15.909108
# 67320               at best   -15.542065
# 240955                didnt   -15.483119
# 164643               caused   -15.003217
# 755273               poorly   -14.798718
# 1036481           two stars   -14.701701
# 664722              no good   -14.611687
# 76937                   bad   -14.532221
# 673738            not great   -14.091071
# 360717              garbage   -13.885221
# 512533                 junk   -13.579574
# 243799       disappointment   -13.519999
# 708682             one star   -13.479054
# 253031                 dont   -13.397531
# 67053                at all   -13.395272
# 211426                 crap   -13.143476
# 666488           no results   -13.037724
# 920246                sucks   -13.005533
# 1021237                 too   -12.974265
# ...                     ...          ...
# 516124            just what    11.726500
# 1119309           wonderful    11.785454
# 240118            didn fail    12.002174
# 670831            not cheap    12.154520
# 1100229             why not    12.269150
# 1021720            too cute    12.331722
# 1127751          works well    12.352865
# 576906               lovely    12.618118
# 106302          better than    12.812104
# 299519             favorite    13.165342
# 674541             not junk    13.657217
# 450820                helps    13.734039
# 578459                loves    13.904978
# 677918           not so bad    14.179436
# 307716              finally    14.262349
# 376552                 good    14.680848
# 295721            fantastic    15.035073
# 671442   not disappointment    15.510066
# 20370               amazing    15.586652
# 671429     not disappointed    16.517949
# 566887                 love    17.297877
# 71812               awesome    17.893004
# 679735              not too    18.049412
# 96964                  best    19.382181
# 673667           not greasy    19.713554
# 674212         not horrible    19.784011
# 736510              perfect    20.828358
# 279386            excellent    21.072047
# 670005              not bad    26.799214
# 396471                great    29.833182
#
# [1148331 rows x 2 columns]

# %% [markdown]
# ### Testing the sentiments of few reviews

# %%
def testSentiments(model, testData):
    testCounts = countVector.transform([testData])
    testTfidf = tfidf_transformer.transform(testCounts)
    result = model.predict(testTfidf)[0]
    probability = model.predict_proba(testTfidf)[0]
    print("Sample estimated as %s: negative prob %f, positive prob %f" % (result.upper(), probability[0], probability[1]))

testSentiments(logreg, "Heavenly Highway Hymns")
testSentiments(logreg, "Very oily and creamy. Not at all what I expected... ordered this to try to highlight and contour and it just looked awful!!! Plus, took FOREVER to arrive.")
testSentiments(logreg, "Nasty smelling shampoo!.")
# Out:
# Sample estimated as POSITIVE: negative prob 0.003317, positive prob 0.996683
# Sample estimated as NEGATIVE: negative prob 0.998970, positive prob 0.001030
# Sample estimated as NEGATIVE: negative prob 0.934181, positive prob 0.065819
